# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
path = Path(r"C:\Users\holys\projs\BaThesis\data\parlam\ParlaMint-UA_extracted.csv")
df = pd.read_csv(path)
# Out:
# C:\Users\holys\AppData\Local\Temp\ipykernel_9336\4215291462.py:2: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
df = pd.read_csv("/Users/anna/projs/BA/BaThesis/data/parlam/ParlaMint-UA_extracted.csv")
df
# Out:
# /var/folders/wh/q4jj7wr52xd5c3g7nmfm2zvr0000gn/T/ipykernel_46243/3224756557.py:1: DtypeWarning: Columns (0: kinesic_types) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/anna/projs/BA/BaThesis/data/parlam/ParlaMint-UA_extracted.csv")

# %%
df.sample(10) #1032770
# Out:
#             corpus_id country        date                      doc_id  \
# 1579519  ParlaMint-UA      UA  2019-02-08  ParlaMint-UA_2019-02-08-m0
# 1276756  ParlaMint-UA      UA  2016-03-31  ParlaMint-UA_2016-03-31-m0
# 1032770  ParlaMint-UA      UA  2013-03-21  ParlaMint-UA_2013-03-21-m1
# 705176   ParlaMint-UA      UA  2009-12-01  ParlaMint-UA_2009-12-01-m1
# 917847   ParlaMint-UA      UA  2011-10-19  ParlaMint-UA_2011-10-19-m0
# 1422648  ParlaMint-UA      UA  2017-09-19  ParlaMint-UA_2017-09-19-m1
# 1929848  ParlaMint-UA      UA  2021-12-03  ParlaMint-UA_2021-12-03-m0
# 1748918  ParlaMint-UA      UA  2020-03-04  ParlaMint-UA_2020-03-04-m0
# 1886928  ParlaMint-UA      UA  2021-07-15  ParlaMint-UA_2021-07-15-m0
# 254798   ParlaMint-UA      UA  2004-09-10  ParlaMint-UA_2004-09-10-m0
#
#         doc_lang                    doc_ana    text_ana  meeting_term  \
# 1579519       uk  #parla.sitting #reference  #reference             8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2033188 entries, 0 to 2033187
# Data columns (total 37 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   corpus_id           object
#  1   country             object
#  2   date                object
#  3   doc_id              object
#  4   doc_lang            object
#  5   doc_ana             object
#  6   text_ana            object
#  7   meeting_term        int64
#  8   meeting_session     int64
#  9   meeting_sitting     object
#  10  source_doc_url      object
#  11  div_type            object
#  12  section_head        float64
#  13  pre_u_note_types    object
#  14  pre_u_notes         object
#  15  speaker             object
#  16  speaker_id          object
#  17  party               object
#  18  speaker_type        object
#  19  speaker_type_label  object
#  20  topic_code          object
#  21  topic_label         object
#  22  ana_raw             object
# ...

# %%
df['party'].value_counts().plot(kind='bar', figsize=(20, 6))
# Out:
# <Axes: xlabel='party'>

# %%
df['speaker_type'].value_counts().plot(kind='bar', figsize=(5, 6))
# Out:
# <Axes: xlabel='speaker_type'>

# %%
df['topic_label'].value_counts().plot(kind='bar', figsize=(5, 6))
# Out:
# <Axes: xlabel='topic_label'>

# %%
df['content_kind'].sample(10)
# Out:
# 1647318            speech
# 602079     speaker_marker
# 1243812            speech
# 520808     speaker_marker
# 1626623            speech
# 982946     speaker_marker
# 379371             speech
# 1381658    speaker_marker
# 982053             speech
# 120400             speech
# Name: content_kind, dtype: object

# %%
for idx, row in df[(df['content_kind'] == 'speech') & (df['topic_label'] != 'other')].sample(20).iterrows():
    print(f"Speaker: {row['speaker']}, Party: {row['party']}, Text: {row['text']}, Topic: {row['topic_label']}, Date: {row['date']}")
# Out:
# Speaker: Володимир Михайлович Литвин, Party: бЛитвин, Text: Олександр Пеклушенко, фракція Партії регіонів., Topic: Other, Date: 2011-05-17
# Speaker: Ірина Володимирівна Геращенко, Party: БПП, Text: Будь ласка, пані Бєлькова, прошу вас до слова, пані Оля., Topic: Other, Date: 2018-05-17
# Speaker: Андрій Володимирович Парубій, Party: НФ, Text: Зареєстровано 307 народних депутатів. Ранкове пленарне засідання Верховної Ради України оголошую відкритим., Topic: Other, Date: 2019-06-19
# Speaker: Вікторія Михайлівна Войціцька, Party: Самопоміч, Text: Тому, закінчуючи, я би хотіла сказати, що вам не консультації треба проводити, пан Вовк, з громадськістю, а треба писати заяву про звільнення і не ховатися за 18-ма місяцями індульгенції, які вам надав Президент України. Звільняйтесь!, Topic: Energy, Date: 2017-04-12
# ...

# %%
df['date']
# Out:
# 0          2002-05-14
# 1          2002-05-14
# 2          2002-05-14
# 3          2002-05-14
# 4          2002-05-14
#               ...
# 2033183    2023-11-10
# 2033184    2023-11-10
# 2033185    2023-11-10
# 2033186    2023-11-10
# 2033187    2023-11-10
# Name: date, Length: 2033188, dtype: str
